# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 609

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
unit = "imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + unit
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taro
# Processing Record 2 of Set 1 | blackmans bay
# Processing Record 3 of Set 1 | udachny
# Processing Record 4 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | atafu village
# Processing Record 7 of Set 1 | amga
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | luderitz
# Processing Record 10 of Set 1 | chiredzi
# Processing Record 11 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 12 of Set 1 | papatowai
# Processing Record 13 of Set 1 | dudinka
# Processing Record 14 of Set 1 | harnoli
# Processing Record 15 of Set 1 | waitangi
# Processing Record 16 of Set 1 | great falls
# Processing Record 17 of Set 1 | port lincoln
# Processing Record 18 of Set 1 | mwinilunga
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | chibougamau
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           taro  -8.3862  115.2800     80.60        48          49
# 1  blackmans bay -43.0167  147.3167     61.74        60          70
# 2        udachny  66.4167  112.4000    -11.07        85          93
# 3      adamstown -25.0660 -130.1015     73.15        81         100
# 4  atafu village  -8.5421 -172.5159     85.24        74          95
#
#    Wind Speed Country        Date
# 0        5.50      ID  1703052565
# 1        1.99      AU  1703052565
# 2        5.12      RU  1703052565
# 3       15.12      PN  1703052565
# 4       10.31      TK  1703052565

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 taro  -8.3862  115.2800     80.60        48          49
# 1        blackmans bay -43.0167  147.3167     61.74        60          70
# 2              udachny  66.4167  112.4000    -11.07        85          93
# 3            adamstown -25.0660 -130.1015     73.15        81         100
# 4        atafu village  -8.5421 -172.5159     85.24        74          95
#
#          Wind Speed Country        Date
# City_ID
# 0              5.50      ID  1703052565
# 1              1.99      AU  1703052565
# 2              5.12      RU  1703052565
# 3             15.12      PN  1703052565
# 4             10.31      TK  1703052565

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], linewidths=1, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], linewidths=1, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], linewidths=1, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], linewidths=1, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on emisphere data
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    
    # Print r squared value and correlation
    print(f"The r-squared value is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    
    # Display Plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        udachny  66.4167  112.4000    -11.07        85          93
# 5           amga  60.8953  131.9608    -43.58        99          89
# 6         albany  42.6001  -73.9662     27.59        74          26
# 10       dudinka  69.4058   86.1778      7.68        76         100
# 11       harnoli  32.2792   71.5539     70.18        16          81
#
#          Wind Speed Country        Date
# City_ID
# 2              5.12      RU  1703052565
# 5              0.43      RU  1703052565
# 6              3.00      US  1703051987
# 10            30.00      RU  1703052566
# 11             4.23      PK  1703052566

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 taro  -8.3862  115.2800     80.60        48          49
# 1        blackmans bay -43.0167  147.3167     61.74        60          70
# 3            adamstown -25.0660 -130.1015     73.15        81         100
# 4        atafu village  -8.5421 -172.5159     85.24        74          95
# 7             luderitz -26.6481   15.1594     67.95        52           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.50      ID  1703052565
# 1              1.99      AU  1703052565
# 3             15.12      PN  1703052565
# 4             10.31      TK  1703052565
# 7             14.03     NaN  1703052565

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function
plot_linear_regression(x_values, y_values, 
                       "Temperature vs Latitude in the \n Northern Hemisphere", 
                       "Max Temp", (5,-40))
# Out:
# The r-squared value is: 0.6911296883669803
# The correlation between both factors is -0.83

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Call the function
plot_linear_regression(x_values, y_values, 
                       "Temperature vs Latitude in the \n Southern Hemisphere",
                       "Max Temp", (-30,40))
# Out:
# The r-squared value is: 0.39303710992904106
# The correlation between both factors is 0.63

# %% [markdown]
# **Discussion about the linear relationship:** These scatter plots show a strong relationhip between max temperature and latitude. As expected, as you approach the equator, the temperatures increase. This is reflected in the Northern Hemisphere plot, where you can see as the points move further away from the equator (Latitude = 0) the temperatures decrease. The same is reflected in the Southern Hemisphere chart, where we see temperatures rise as we move towards the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Call the function
plot_linear_regression(x_values, y_values, 
                       "Humidity vs Latitude in the \n Northern Hemisphere",
                       "Humidity", (40,20))
# Out:
# The r-squared value is: 0.23313454915507578
# The correlation between both factors is 0.48

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Call the function
plot_linear_regression(x_values, y_values, 
                       "Humidity vs Latitude in the \n Southern Hemisphere",
                       "Humidity", (-25, 25))
# Out:
# The r-squared value is: 0.040048318494614245
# The correlation between both factors is 0.2

# %% [markdown]
# **Discussion about the linear relationship:** These scatter plots do not reflect a strong relationship between between humidity and latitude, however a visible cluster of northern hemisphere locations with high humiditiy (80% and above) is visible in the plot.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Call the function
plot_linear_regression(x_values, y_values, 
                       "Cloudiness vs Latitude in the \n Northern Hemisphere",
                       "Cloudiness", (40,45))
# Out:
# The r-squared value is: 0.038036487917166996
# The correlation between both factors is 0.2

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Call the function
plot_linear_regression(x_values, y_values, 
                       "Cloudiness vs Latitude in the \n Southern Hemisphere",
                       "Cloudiness", (-55, 60))
# Out:
# The r-squared value is: 0.09443771379282653
# The correlation between both factors is 0.31

# %% [markdown]
# **Discussion about the linear relationship:** These plots do not reflect a strong relationship between between cloudiness and distance from the equator. However, on an interesting note, in both the northern and southern hemispheres a strong concentration of locations with ether 0% or 100% cloudiness is visible.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Call the function
plot_linear_regression(x_values, y_values, 
                       "Wind Speed vs Latitude in the \n Northern Hemisphere",
                       "Wind Speed", (10,27))
# Out:
# The r-squared value is: 0.012550070051092887
# The correlation between both factors is 0.11

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Call the function
plot_linear_regression(x_values, y_values,
                       "Wind Speed vs Latitude in the \n Southern Hemisphere",
                       "Wind Speed", (-50, 30))
# Out:
# The r-squared value is: 0.019002659976256712
# The correlation between both factors is -0.14

# %% [markdown]
# **Discussion about the linear relationship:** These plots do not reflect any strong relationship between between wind speed and latitude, however wind speeds do slightly increase while moving away from the equator.
